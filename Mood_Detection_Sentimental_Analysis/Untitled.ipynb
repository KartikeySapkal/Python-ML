# %%
import pandas as pd

# %%
df = pd.read_csv("Sentiment_Analysis.csv")
df
# Out:
#     Unnamed: 0  Emotion                                               Text  \
# 0            0  neutral                                              Why ?
# 1            1    happy    Sage Act upgrade on my to do list for tommorow.
# 2            2      sad  ON THE WAY TO MY HOMEGIRL BABY FUNERAL!!! MAN ...
# 3            3    happy  Such an eye ! The true hazel eye-and so brilli...
# 4            4    happy  @Iluvmiasantos ugh babe.. hugggzzz for u .! ba...
# 5            5      sad  I'm expecting an extremely important phonecall...
# 6            6      sad  .Couldnt wait to see them live. If missing the...
# 7            7  neutral  maken Tip 2: Stop op een moment dat je het hel...
# 8            8  neutral  En dan krijg je ff een cadeautje van een tweep...
# 9            9  neutral  @1116am Drummer Boy bij op verzoek van @BiemOo...
# 10          10      sad  The bull tossed the effigy out of their hands ...
# 11          11      sad            People hide their behind a #fake smile.
# 12          12    happy  For once in his life , Leopold must have been ...
# 13          13      sad  Against the assault of laughter nothing can st...
# 14          14      sad  With everything , with everybody , with all th...
# 15          15      sad  Shakuhachi dress $580, 10-22 mm lens $708 #pai...
# 16          16  neutral  Haha of course I come home to a different hous...
# 17          17    happy    I have a feeling i will fail french #fuckfrench
# 18          18    happy                              Good.Let ' s go now .
# 19          19  neutral  @JuliaLeader I reeeeeellllyyyyyyy need to tell...
# 20          20      sad     Oh , that's too bad . Should I call a doctor ?
# 21          21    happy  When I fell in love with \X\". Overnight I fel...
# 22          22      sad  is a primitive #Instinct that's your friend.It...
# 23          23      sad                            I have to talk to you !
# 24          24      sad  I was riding with a friend in his car. At a sp...
# 25          25      sad  you're so welcome @madelineerich8! so glad I c...
# 26          26  neutral  another ending? i almost pooped my pants at th...
# 27          27    happy  One could get terribly ecstatic but that would...
# 28          28      sad  So much for losing something.. Going to fat bu...
# 29          29    happy   When I was selected to study here at university.
# 30          30    happy   Yeah , it ’ s been ages ! So how have you been ?
# 31          31      sad  is a friend that you misunderstood but I know ...
# 32          32      sad  @nicolescherzy @nicosherzinger & &#xA;&#xA;Add...
# 33          33  neutral  Nobody doubted him , or failed to recognise hi...
# 34          34      sad  The bank had made no secret of their dismay ov...
# 35          35    happy  When I passed the B.A exams with first class r...
# 36          36      sad  homies all go to ride ponies... I look at them...
# 37          37  neutral              pop out &amp; roll across the floor !
# 38          38      sad  OMG its December 5th and the windows are open ...
# 39          39  neutral  alleen nog even morgen cadootjes kopen in stad...
# 40          40  neutral  I'm not from this planet, I'm from one of the ...
# 41          41      sad  When you kill yourself with work and see the n...
#
#                                            Clean_Text
# 0                                                 NaN
# 1                      Sage Act upgrade list tommorow
# 2   WAY HOMEGIRL BABY FUNERAL MAN HATE FUNERALS SH...
# 3   eye true hazel eyeand brilliant Regular featur...
# 4   ugh babe hugggzzz u babe naamazed nga ako e ba...
# 5   Im expecting extremely important phonecall min...
# 6   Couldnt wait live missing NH7 wasnt painful en...
# 7   maken Tip 2: Stop op een moment dat je het hel...
# 8   En dan krijg je ff een cadeautje van een tweep...
# 9   Drummer Boy bij op verzoek van : welke uitvoer...
# 10                bull tossed effigy hands infuriated
# 11                            People hide #fake smile
# 12  life Leopold truly happy : hopes prayers belov...
# 13  assault laughter stand ~ Mark Twain #emotional...
# 14                                          everybody
# 15   Shakuhachi dress $580 1022 mm lens $708 #pain :(
# 16  Haha course come home different house leave pa...
# 17                    feeling fail french #fuckfrench
# 18                                            GoodLet
# 19  reeeeeellllyyyyyyy need tell something guess w...
# 20                                Oh thats bad doctor
# 21  fell love \X\ Overnight felt confidence selfes...
# 22  primitive #Instinct thats friendIt warns pay a...
# 23                                               talk
# 24  riding friend car speed 120 km/h snowcovered m...
# 25  welcome glad night love you leave :( im gonna ...
# 26  ending pooped pants end weeks crazy ending #dE...
# 27                  terribly ecstatic dangerous thing
# 28       losing something Going fat burger dinner dad
# 29                          selected study university
# 30                                        Yeah ’ ages
# 31        friend misunderstood know #heartoflife good
# 32  #xA#xAAdd things symptom called #NERVOSO #xA#x...
# 33  doubted failed recognise temporary financial e...
# 34       bank secret dismay Virgin s venture airlines
# 35                      passed BA exams class results
# 36  homies ride ponies look like sad puppy #wantto...
# 37                                 pop amp roll floor
# 38  OMG December 5th windows open house Mr Winter ...
# 39  alleen nog morgen cadootjes kopen stadje en da...
# 40      Im planet Im planets hold life amp discovered
# 41  kill work number slakers wandering around nothing

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score

# Load your dataset
df = pd.read_csv('Sentiment_Analysis.csv')

# Replace missing values (NaN) with empty strings
df['Clean_Text'].fillna('', inplace=True)

# Split the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(df['Clean_Text'], df['Emotion'], test_size=0.2, random_state=42)

# Vectorize the text data using TF-IDF
tfidf_vectorizer = TfidfVectorizer(max_features=5000)  # You can adjust max_features as needed
X_train_tfidf = tfidf_vectorizer.fit_transform(X_train)
X_test_tfidf = tfidf_vectorizer.transform(X_test)

# Train a Multinomial Naive Bayes classifier
nb_classifier = MultinomialNB()
nb_classifier.fit(X_train_tfidf, y_train)

# Predict sentiment on the test set
y_pred = nb_classifier.predict(X_test_tfidf)

# Evaluate the classifier
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# Save the trained model to a file
with open('sentiment_analysis_model.pkl', 'wb') as model_file:
    pickle.dump(nb_classifier, model_file)
# Out:
# Accuracy: 0.2222222222222222
